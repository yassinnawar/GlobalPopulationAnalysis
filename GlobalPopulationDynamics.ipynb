# %% [markdown]
# # <center> Global Population Dynamics: Uncovering Insights into Growth, Decline, and Their Socioeconomic Effects<center>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 ) Research Objectives:
# ### The primary aim of this project is to delve into the dynamics of global population changes and understand their multi-faceted aspects.
#
# ### The objectives of the research are:
#     a. Analyzing the patterns of growth in the global population, with a particular emphasis on
#        the top five most populated countries.
#
#     b. Examining the influential factors contributing to these changes, such as Gross
#        Domestic Product (GDP) progression, age distribution, and age dependency ratios.

# %% [markdown]
# ### 1.2 ) Data Acquisition:
# > #### The primary data for this project was obtained from the World Bank Open Data portal, which provides free and open access to global development data.
# > #### The specific dataset used in this project is the "Population, total" dataset, which presents the total population figures for various countries across the world, spanning from the 1960s up to 2022.

# %% [markdown]
# ### 1.3 ) Exploratory Data Analysis:
#
# > #### Preliminary analysis of the dataset was conducted using Python and its libraries including pandas and matplotlib.
# ### The following observations were made:
#
#     a.The data consists of annual population figures for each country.
#
#     b. There were some inconsistencies in the data, such as entries for non-country entities
#        (e.g., 'World', 'IDA & IBRD total',Contintents such as:Asia,Africa etc.) which were subsequently
#        cleaned.
#
#     d. All datasets contained the same empty 4 rows at the beginning. Those were removed manually
#        along with 2 other coloums that contain irrelevant data such as country codes.

# %% [markdown]
# ### 1.4 ) Research Summary:
# > ### The field of population studies is critical due to its direct connection with key global challenges such as urbanization, environmental change, and socio-economic development. Understanding population dynamics is essential in policy planning, resources allocation, and tackling developmental issues. This research focuses on understanding global population changes and its implications, thereby contributing to the broader field of population studies.

# %% [markdown]
# ## 2. Justification of Data Source

# %% [markdown]
# ### 2.1 ) Origin and Acquisition of Data:
# > The dataset used in this project originates from the World Bank's open data platform. The World Bank curates and manages a massive collection of development data from officially-recognized international sources. This particular dataset, "Population, total", contains yearly population counts for all countries and territories recognized by the World Bank, from the 1960s through 2022.
#
# > The dataset was downloaded directly from the World Bank Open Data website in CSV format. It was subsequently loaded into a Jupyter notebook using the pandas library for further cleaning, processing, and analysis.

# %% [markdown]
# ### 2.2 ) Relevance of Data to Research Question
#
# #### The "Population, total" dataset from the World Bank is particularly appropriate for the research question at hand because:
#
#     a. It covers a broad time period (1960-2022), allowing for an analysis of long-term trends
#        in population growth and decline.
#
#     b. It includes data for all the recognized countries, enabling comparisons between different
#         regions and countries.
#
#     c. The dataset is sourced from a reputable international organization, ensuring the reliability and
#        accuracy of the data.
#
#
#
#
# > #### The research questions revolve around population trends and their implications, and this dataset provides direct and comprehensive information about global population figures over time.

# %% [markdown]
# ### 2.3 ) Comparison with Other Datasets:
# #### While the World Bank's "Population, total" dataset was chosen for this project, other potential datasets were also considered.
#
# ### These include:
#     a. United Nations Population Division's World Population Prospects: This dataset provides
#        comprehensive demographic data, including population counts, fertility rates, mortality rates
#        and migration data. However, it is updated less frequently and its format is not as easily
#        manageable as the World Bank's data.
#
#     b. Data from national statistical agencies: These datasets often provide the most
#        detailed and accurate population data for individual countries. However, collating this data from
#        multiple sources would have been time-consuming, and inconsistencies in data collection methods
#        across different countries could have posed problems for the analysis.

# %% [markdown]
# ### 3.1 ) Relevance and Interest:
# > ### Population dynamics are at the core of many critical issues facing the world today, ranging from economic development and resource management to healthcare planning and environmental sustainability. Studying population trends can provide valuable insights into a myriad of socio-economic and environmental aspects on a global scale. As a researcher with an interest in demographics and its implications, this field offers a rich ground for inquiry and analysis.

# %% [markdown]
# ### 3.2 ) Scope of Work:
#
# ### In this project, the focus will primarily be on:
#
#     a. Identifying the top 5 countries in terms of population growth over the period from 1960 to 2022.
#
#     b. Investigating the patterns of population growth, decline, and distribution in these countries.
#
#     c. Assessing the potential impacts of these population trends on GDP and age distribution

# %% [markdown]
# ### 3.3 ) Analytical Data Processing Pipeline:
#
# ### The data processing steps for this project are as follows:
#
#     1. Data acquisition: Downloading the dataset in CSV format from the World Bank Open Data website.
#
#     2. Data cleaning: Removing entries for non-country territories and cleaning up the country names.
#
#     3. Data exploration: Reviewing the cleaned dataset to understand its structure and contents.
#
#     4. Conducting various analyses

# %% [markdown]
# ### 3.4 ) Evaluation Methodology
#
#
# > The aims and objectives of this project will be evaluated based on the depth and breadth of the analysis conducted and the insights generated.
#
# #### Key evaluation points will include:
#     a- The extent to which the research questions were addressed.
#     b- The clarity and comprehensiveness of the data analysis.
#     c- The soundness of the conclusions drawn from the analysis.

# %% [markdown]
# ## 4. Technical Exploration of Dataset
#
# In this section, we will technically explore the dataset. The purpose of this exploration is to understand the data's characteristics, structure, and potential issues that may need addressing. The technical exploration of data usually involves two main steps: Data Cleaning and Formatting, and Exploratory Analysis and Insights.

# %% [markdown]
# ### 4.1 ) Data Cleaning and Formatting
# > Data Cleaning and Formatting is a critical step in any data analysis process. It involves preparing and structuring the dataset in a manner suitable for analysis.

# %%
import pandas as pd
# read the csv file
populationData = pd.read_csv('population.csv', skiprows=0)
populationData.head(10)
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
# 5                      Albania    1608800.0    1659800.0    1711319.0
# 6                      Andorra       9443.0      10216.0      11014.0
# 7                   Arab World   93359407.0   95760348.0   98268683.0
# 8         United Arab Emirates     133426.0     140984.0     148877.0
# 9                    Argentina   20349744.0   20680653.0   21020359.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# ...

# %% [markdown]
# ### After Examining the first 10 items from the dataset, we can clearly notice that there are entries in the countries coloums that don't correspond to real countries. These will be printed out in the next cell. These include Continents, parts of Continents and others. Some of the keywords used for removal were obtained by listing the head each time until only countries appear.

# %%
#Print all the rows that are going to be removed
removed_rows = []
removed_rows = populationData[populationData['Country Name'].str.contains('world', case=False, na=False)]
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('income', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('demographic', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('eastern', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('western', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('Asia', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('Euro', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains(r'\bAfrica\b', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains(r'\bAmerica\b', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('IBRD', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('members', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains(r'\bIDA\b', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains(r'\bUN\b', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('countries', case=False, na=False)]])
removed_rows = pd.concat([removed_rows, populationData[populationData['Country Name'].str.contains('conflict', case=False, na=False)]])

pd.set_option('display.max_rows', None)

# Print the removed rows' names in a table
print("Removed Rows:")
print(removed_rows[['Country Name']])
# Out:
# Removed Rows:
#                                           Country Name
# 7                                           Arab World
# 258                                              World
# 61         East Asia & Pacific (excluding high income)
# 64       Europe & Central Asia (excluding high income)
# 95                                         High income
# 127  Latin America & Caribbean (excluding high income)
# 135                                         Low income
# 138                                Lower middle income
# 139                                Low & middle income
# 155                                      Middle income
# 160  Middle East & North Africa (excluding high inc...
# 214         Sub-Saharan Africa (excluding high income)
# 248                                Upper middle income
# 62                          Early-demographic dividend
# 141                          Late-demographic dividend
# 190                           Pre-demographic dividend
# ...

# %% [markdown]
# ## Removal Code ⬇️

# %%
# Remove rows where 'Country Name' contains the word 'world'
populationData = populationData[~populationData['Country Name'].str.contains('world', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'income'
populationData = populationData[~populationData['Country Name'].str.contains('income', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'demographic'
populationData = populationData[~populationData['Country Name'].str.contains('demographic', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'eastern'
populationData = populationData[~populationData['Country Name'].str.contains('eastern', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'western'
populationData = populationData[~populationData['Country Name'].str.contains('western', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'Asia'
populationData = populationData[~populationData['Country Name'].str.contains('Asia', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'Euro'
populationData = populationData[~populationData['Country Name'].str.contains('Euro', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'Africa'
populationData = populationData[~populationData['Country Name'].str.contains(r'\bAfrica\b', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'America' (note: this will not remove American)
populationData = populationData[~populationData['Country Name'].str.contains(r'\bAmerica\b', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'IBRD'
populationData = populationData[~populationData['Country Name'].str.contains('IBRD', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'members'
populationData = populationData[~populationData['Country Name'].str.contains('members', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'IDA'
populationData = populationData[~populationData['Country Name'].str.contains(r'\bIDA\b', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'UN'
populationData = populationData[~populationData['Country Name'].str.contains(r'\bUN\b', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'countries'
populationData = populationData[~populationData['Country Name'].str.contains('countries', case=False, na=False)]

# Remove rows where 'Country Name' contains the word 'conflict'
populationData = populationData[~populationData['Country Name'].str.contains('conflict', case=False, na=False)]

# %%
populationData.head(10)
# Out:
#             Country Name        1960        1961        1962        1963  \
# 0                  Aruba     54608.0     55811.0     56682.0     57475.0
# 2            Afghanistan   8622466.0   8790140.0   8969047.0   9157465.0
# 4                 Angola   5357195.0   5441333.0   5521400.0   5599827.0
# 5                Albania   1608800.0   1659800.0   1711319.0   1762621.0
# 6                Andorra      9443.0     10216.0     11014.0     11839.0
# 8   United Arab Emirates    133426.0    140984.0    148877.0    157006.0
# 9              Argentina  20349744.0  20680653.0  21020359.0  21364017.0
# 10               Armenia   1904148.0   1971530.0   2039346.0   2106142.0
# 11        American Samoa     20085.0     20626.0     21272.0     21949.0
# 12   Antigua and Barbuda     55342.0     56245.0     57008.0     57778.0
#
#           1964        1965        1966        1967        1968  ...      2013  \
# 0      58178.0     58782.0     59291.0     59522.0     59471.0  ...    102880
# ...

# %% [markdown]
# ### As a test, we will print out the top 20 countries in population, we should get accurate country values by now.

# %%
most_populated_countries = populationData.sort_values('2022', ascending=False).head(20)
print(most_populated_countries["Country Name"])
# Out:
# 109                 India
# 40                  China
# 250         United States
# 106             Indonesia
# 183              Pakistan
# 173               Nigeria
# 29                 Brazil
# 20             Bangladesh
# 201    Russian Federation
# 153                Mexico
# 118                 Japan
# 72               Ethiopia
# 186           Philippines
# 67       Egypt, Arab Rep.
# 43       Congo, Dem. Rep.
# 256               Vietnam
# 111    Iran, Islamic Rep.
# 243               Turkiye
# 55                Germany
# 232              Thailand
# Name: Country Name, dtype: object

# %% [markdown]
# ## Now our Data Frame is clean and ready to be used.

# %% [markdown]
# ### 4.2 ) Exploratory Analysis and Insights:
#
# ### In this section, we'll perform an exploratory analysis of the population growth over time for our top countries of interest. This will give us an idea of the overall trends and patterns in population change.
#
# > We'll start by creating a line plot of population against time for each country. Line plots are a great way to visualize changes over time since they allow us to easily see rising and falling trends. We're particularly interested in seeing how these trends differ between countries.
#
# >>  To do this, we'll loop through our top countries, extract the corresponding population data from our main dataset, and plot it on the graph. We'll use different colors for each country for easy comparison.
#
# ## Let's go ahead and create our plot.

# %%
import matplotlib.pyplot as plt

# Create an empty plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot population growth for each country
for country in most_populated_countries["Country Name"]:
    country_data = populationData[populationData["Country Name"] == country]
    years = range(1960, 2023)  # Update this range with the actual years in your data
    populations = country_data.loc[:, str(years[0]):str(years[-1])].values[0]
    ax.plot(years, populations, label=country)

# Add legend, title, and labels
ax.legend()
ax.set_title('Population Growth Over Time (1960-2022)')
ax.set_xlabel('Year')
ax.set_ylabel('Population')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Code Efficiency: Creating a Function for Plotting Population Growth
#
# ### In line with best programming practices, we aim for code that is clean, clear, and efficient. A key strategy to achieve this is the "Don't Repeat Yourself" (DRY) principle, which reduces redundancy and enhances readability and maintainability.
#
# In keeping with the DRY principle, we've developed the function plot_population_growth to plot population growth for various countries across different time periods. Without this function, we would have to duplicate several lines of code each time we wanted to create a similar plot, but with a different set of countries or a different time period.
#
# > By encapsulating this code in a function, we can easily generate as many of these plots as we need by simply calling the function with different arguments. This approach keeps our code base concise, easy to understand, and easy to manage.
#
# >> In addition, encapsulating this code in a function also enhances code readability and makes it easier to identify and debug any issues that may arise. It simplifies our code structure, and makes it more straightforward to follow the flow of our data processing and analysis steps.
#
# > We've also added a function to clean our data frame
#
# ## Plotting Function Code⬇️

# %%
import matplotlib.pyplot as plt

def plot_population_growth(countries, start_year, end_year, num_countries):
    # Create an empty plot
    fig, ax = plt.subplots(figsize=(12, 8))

    # Plot population growth for each country
    for country in countries[:num_countries]:
        country_data = populationData[populationData["Country Name"] == country]
        years = range(start_year, end_year + 1)  # Update this range with the desired start and end years
        populations = country_data.loc[:, str(years[0]):str(years[-1])].values[0]
        ax.plot(years, populations, label=country)

    # Add legend, title, and labels
    ax.legend()
    ax.set_title('Population Growth Over Time ({}-{})'.format(start_year, end_year))
    ax.set_xlabel('Year')
    ax.set_ylabel('Population')

    # Show the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Data Cleaning Function Code⬇️

# %%
def clean_data(df):
    filters = ['world', 'income', 'demographic', 'eastern', 'western', 'Asia', 
               'Euro', r'\bAfrica\b', r'\bAmerica\b', 'IBRD', 'members', 
               r'\bIDA\b', r'\bUN\b', 'countries', 'conflict']

    for word in filters:
        df = df[~df['Country Name'].str.contains(word, case=False, na=False)]

    return df

# %% [markdown]
# ## <center> 5. Data Analysis<center>

# %% [markdown]
# ### 5.1 ) Focusing on Top 5 Countries Population in 2022
# After obtaining a broad overview of global population trends, let's now narrow our focus to the top 5 countries with the largest populations in 2022. These countries, namely India, China, the United States, Indonesia, and Pakistan, account for a significant portion of the world's population. Analyzing their population growth over time gives us valuable insights into their unique demographic dynamics.
#
# ### In the line plot that follows, we will track the population changes of these five countries from 1960 to 2022. Understanding the evolution of these countries' population growth will enable us to better understand the global trends in population change, especially considering their significant contributions to the world's total population.
#
# >  In the next cell, we will generate this line plot using our created plot_population_growth function, specifying the number of countries to be 5 and the end year as 2022.

# %%
plot_population_growth(most_populated_countries["Country Name"], 1960, 2022, 5)

# %% [markdown]
# ### The population growth plot above  provides several insightful observation.
#
#     a.  India: India shows a consistent and steady growth in population over the observed period.
#                The rate of growth appears to be linear, suggesting a fairly stable increase in
#                population year on year.
#
#     b. China: China, similar to India, also shows a steady increase in population over time. However, there
#               appears to be a subtle deceleration in recent years, suggesting a slowdown in the rate of
#               population growth. This could be influenced by several factors, including
#               government policies, which might require further investigation.
#
#     c. United States: The United States also shows a consistent growth trend, albeit at a lower rate
#                       compared to India and China. The trend line is smoother, indicating less
#                       fluctuation in the growth rate over the years.
#
#     d. Indonesia: Indonesia's population growth is fairly steady, with a slight slowdown in recent years
#                   similar to China. This is indicative of a strong and consistent growth trend,
#                   albeit with some deceleration.
#
#     e. Pakistan: Pakistan exhibits a steeper increase in population compared to the United States
#                  and Indonesia.

# %% [markdown]
# ### 5.2 ) Comparative Analysis of Population Growth: India vs China (2000-2010)
#
# >#### In the next analysis, we will specifically focus on the population growth trends of the top two populous countries: India and China. We will visualize and examine the population growth from 2000 to 2010 for these two nations.

# %%
plot_population_growth(most_populated_countries["Country Name"], 2000, 2010, 2)

# %% [markdown]
# ### Insights:
#
# ### From the graph, it is observed that China's population growth started to decelerate during 2000-2010. Various factors could have contributed to this trend, potentially reflecting the impact of demographic policies implemented by the Chinese government during this period.
#
# ### On the other hand, India's population growth remained consistently linear during these years, indicating a steady increase in population over time.

# %% [markdown]
# ### Comparative Analysis of Population Growth: India vs China (2010-2020)
#
# >#### Next, we will move our focus to the following decade (2010-2020) and observe the population trends in the same two countries: India and China.

# %%
plot_population_growth(most_populated_countries["Country Name"], 2010, 2020, 2)

# %% [markdown]
# ### Insights:
#
# ### The plot shows that India's population growth continues to follow a linear trajectory from 2010-2020. Interestingly, India's growth rate appears to be outpacing China's during this period, signaling a potential shift in the rank of the world's most populous country.
#
# ### The trend indicates that India may soon surpass China if these population growth patterns continue.

# %% [markdown]
# ### Comparative Analysis of Population Growth: India vs China (2020-2022)
#
# >#### Following our observations in the previous two sections, we now narrow down our focus to the most recent years (2020-2022). We continue to compare the population growth between India and China during these years.

# %%
plot_population_growth(most_populated_countries["Country Name"], 2020, 2022, 2);

# %% [markdown]
# ### Insights:
#
# ### The graph confirms our prior observation - India has indeed overtaken China in terms of population. In the year 2021, India's population surpassed China's, making it the most populous country in the world.
#
# ### This significant demographic shift represents not only an interesting statistic but also sets the stage for potential changes in global dynamics, socio-economic conditions, and policy-making on both domestic and international fronts. Such shifts often have far-reaching implications, impacting areas as diverse as economic development, environmental sustainability, and geopolitics.
#
# ### However, it's crucial to note that while we have derived these insights based on available data, real-world implications are subject to multiple complex factors and should be studied in more depth for a comprehensive understanding.

# %% [markdown]
# ### 5.1 ) Comparative Analysis of Relative and Absolute Population Growth
#
# >#### To gain more nuanced insights into global population dynamics, we are extending our investigation into two additional aspects: relative population growth rate and absolute population increase. Each of these metrics offers unique perspectives into demographic trends and the factors driving them.

# %% [markdown]
# ### Population Growth Calculation
# Let's start by computing two different metrics for each country in our dataset: the total population growth and the growth rate from 1960 to 2022.
#
# ### The Population Growth is computed as the difference between the population in 2022 and 1960, representing the total increase in population over this period.
#
# ### The Growth Rate is calculated as the ratio of the Population Growth to the initial population in 1960, multiplied by 100 to obtain a percentage. This represents the relative increase in population size over the same period.

# %%
# Calculate the absolute population increase
populationData['Population Growth'] = populationData['2022'] - populationData['1960']

# Calculate the growth rate
populationData['Growth Rate'] = (populationData['Population Growth'] / populationData['1960']) * 100

# %% [markdown]
# Now, let's use our computed metrics to identify the top 10 countries with the highest growth rate and the highest absolute population increase.

# %%
# Sort the data by the growth rate in descending order
top_growth_countries = populationData.sort_values('Growth Rate', ascending=False).head(10)

# Sort the data by the absolute population increase in descending order
top_increase_countries = populationData.sort_values('Population Growth', ascending=False).head(10)

# %% [markdown]
# Next, we display these top 10 countries for both categories:

# %%
# Print the top 10 countries with the highest growth rate and their population growth
print("Top 10 Countries with Highest Growth Rate:")
print(top_growth_countries[['Country Name', 'Growth Rate']])
print()
print("Top 10 Countries with Highest Absolute Population Increase:")
print(top_increase_countries[['Country Name', 'Population Growth']])
# Out:
# Top 10 Countries with Highest Growth Rate:
#                   Country Name  Growth Rate
# 199                      Qatar  7307.233750
# 8         United Arab Emirates  6975.928979
# 224  Sint Maarten (Dutch part)  1539.795918
# 126                     Kuwait  1297.728664
# 117                     Jordan  1230.981230
# 56                    Djibouti  1204.222714
# 22                     Bahrain   816.188834
# 204               Saudi Arabia   774.043197
# 181                       Oman   752.906982
# 6                      Andorra   745.324579
#
# Top 10 Countries with Highest Absolute Population Increase:
#       Country Name  Population Growth
# 109          India        971218594.0
# 40           China        745105000.0
# 183       Pakistan        189870636.0
# 106      Indonesia        187118458.0
# 173        Nigeria        173612870.0
# 250  United States        152616557.0
# 29          Brazil        142220983.0
# 20      Bangladesh        120789943.0
# ...

# %% [markdown]
# ## Let's plot Growth Rate:

# %%
plt.figure(figsize=(20,10)); # Makes the plot larger
ax = top_growth_countries.plot(kind='bar', x='Country Name', y='Growth Rate', legend=False, fontsize=12);
ax.set_title('Top 10 Countries with Highest Growth Rate', fontsize=10)
ax.set_xlabel('Country Name', fontsize=8);
ax.set_ylabel('Growth Rate (%)', fontsize=15);
plt.xticks(rotation=45, ha='right'); # Rotates the labels and aligns them properly
plt.tight_layout();
plt.show();

# %% [markdown]
# ### Qatar and the United Arab Emirates, despite having relatively smaller populations, have seen the most significant percentage increases. This reflects a rapid growth phase, often attributable to factors like high immigration, robust economic growth, or specific governmental policies.

# %% [markdown]
# ## Let's plot Absolute Population Increase:

# %%
# Bar plot for top 10 countries with highest absolute population increase
import seaborn as sns
sns.barplot(x='Population Growth', y='Country Name', data=top_increase_countries, orient='h').set_title('Top 10 Countries with Highest Absolute Population Increase');

# %% [markdown]
#  ### Not surprisingly, the most populous countries, such as India, China, and Pakistan, are also the ones with the highest absolute population increases. These nations have added the most people, contributing significantly to global population growth.
#
# >##### It's noteworthy that the countries topping the relative and absolute growth lists are largely different. This underscores the distinct information these metrics provide. For instance, a country like China, while having a smaller relative growth rate, still contributes significantly to global population growth due to its already large population size. Conversely, a country like Qatar, despite a high growth rate percentage, does not significantly affect global numbers due to its initially smaller population.

# %% [markdown]
# ### In conclusion, the story of population growth is multi-faceted and intricate. It's not solely about which country has the largest population, but also about the pace of growth, both in relative and absolute terms. Recognizing this complexity is vital for policymakers and planners globally, as the impacts of population growth extend across borders and have long-lasting effects on our shared future.

# %% [markdown]
# ## 5.3 ) Incorporating Age Distribution Data:
#
# ### To further enrich our analysis, we will incorporate additional datasets that provide information on the age distribution within countries. This data will allow us to examine population dynamics more closely and could potentially yield insights about factors such as a country's economic prospects, healthcare needs, and social infrastructure requirements.
#
# #### The age distribution datasets we will use are categorized into three distinct groups:
#     a.pop_14.csv: This dataset contains the population size of individuals aged from 0-14 years.
#
#     b. pop_15_64.csv: This dataset contains the population size of individuals aged from 15-64 years,
#     typically considered the working-age population.
#
#     c. pop_65+.csv: This dataset contains the population size of individuals aged 65 years and
#     above, representing the senior population.
#
# >All these datasets are sourced from the World Bank, similar to our original population
#     dataset, ensuring consistency in our data.
#
# ### Let's start by loading these datasets and conducting a preliminary exploration of their content.

# %%
# Load age distribution datasets
pop_14 = pd.read_csv('pop_14.csv')
pop_15_64 = pd.read_csv('pop_15_64.csv')
pop_65 = pd.read_csv('pop_65+.csv')

# Display the first few rows of each dataset
print("Age 0-14 Population Data:")
print(pop_14.head())
print("\n\n")
print("\nAge 15-64 Population Data:")
print(pop_15_64.head())
print("\n\n")
print("\nAge 65+ Population Data:")
print(pop_65.head())
# Out:
# Age 0-14 Population Data:
#                   Country Name       1960       1961       1962       1963  \
# 0                        Aruba  43.131043  42.949419  42.852732  42.661157
# 1  Africa Eastern and Southern  44.200016  44.285569  44.381992  44.495098
# 2                  Afghanistan  41.627186  41.695303  41.769167  41.885377
# 3   Africa Western and Central  41.322373  41.417194  41.529034  41.696118
# 4                       Angola  42.236698  42.728464  43.256801  43.811211
#
#         1964       1965       1966       1967       1968  ...       2013  \
# 0  42.359159  41.936664  41.406296  40.725620  39.949219  ...  19.348756
# 1  44.609810  44.728859  44.854763  44.973533  45.083911  ...  42.933684
# 2  42.059389  42.314133  42.620141  42.918797  43.208375  ...  46.867621
# 3  41.944426  42.168576  42.331521  42.492222  42.647692  ...  44.266677
# 4  44.416202  44.971958  45.449348  45.902722  46.316066  ...  45.756383
#
# ...

# %% [markdown]
# ### We can clearly notice and also expect that we would have the same countries' values we excluded in the population file since they're coming from the same source. After examining the data we conclude that we can use the same data cleaning techniques we've used earlier. We are going to call our cleaning fucntion on the 3 dataframes
#
# ## Data Cleaning:

# %%
pop_14 = clean_data(pop_14);
pop_15_64 = clean_data(pop_15_64);
pop_65 = clean_data(pop_65);

# %% [markdown]
# ### Once we have our age distribution datasets loaded, we can create visualizations to better understand the distribution of different age groups within countries. In the first step, we will create separate visualizations for each age group, and then we will create combined visualizations that show the distributions of all age groups together.

# %% [markdown]
# # Age Distribution Analysis
# > ### We are now going to visualize the age distribution for different countries. For this analysis, we have three separate datasets representing three age groups: 0-14, 15-64, and 65+.
#
# #### These datasets are sorted based on the year 2022, and we are going to focus on the top 10 countries with the highest population in each age group.

# %% [markdown]
# ### <center> Visualization for Ages 0-14 <center>

# %%
# Define a figure
fig, ax = plt.subplots(figsize=(8, 6))

# Visualizations for Age 0-14 Population Data
pop_14.sort_values('2022', ascending=False).head(10).plot(kind='bar', color='skyblue', x='Country Name', y='2022', title='Top 10 Countries with Highest Population Aged 0-14 in 2022', ax=ax);
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### <center> Visualization for Ages 15-64 <center>

# %%
fig, ax = plt.subplots(figsize=(8, 6))

pop_15_64.sort_values('2022', ascending=False).head(10).plot(kind='bar', color='green', x='Country Name', y='2022', title='Top 10 Countries with Highest Population Aged 15-64 in 2022', ax=ax);
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### <center> Visualization for Ages 65+ <center>

# %%
fig, ax = plt.subplots(figsize=(8, 6))

pop_65.sort_values('2022', ascending=False).head(10).plot(kind='bar', color='purple', x='Country Name', y='2022', title='Top 10 Countries with Highest Population Aged 65+ in 2022', ax=ax);
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <center> Merging Age Group Datasets and Visualizing Age Distribution <center>

# %% [markdown]
# #### Now that we have the individual age group datasets loaded and inspected, the next step in our analysis is to merge these datasets together. This will allow us to view the combined age distribution for each country.
#
# #### After merging the datasets, we'll sort the resulting dataframe by the total population in descending order and select the top 10 countries. Then, we will create a stacked bar chart to visualize the distribution of age groups for the top 10 countries in each age group.
#
# ##### A stacked bar chart enables us to compare the total populations while also maintaining a view of the age group distributions.

# %%
# Combine the datasets
combined = pd.merge(pd.merge(pop_14, pop_15_64, on='Country Name'), pop_65, on='Country Name')

# Sort and get top 10 countries for each age group
top_countries_0_14 = combined.sort_values('2022_x', ascending=False).head(10)
top_countries_15_64 = combined.sort_values('2022_y', ascending=False).head(10)
top_countries_65 = combined.sort_values('2022', ascending=False).head(10)

# %% [markdown]
# ## <center> Age Distribution 0-14 <center>

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# Plot a stacked bar chart for Age Group 0-14
ax.bar(top_countries_0_14['Country Name'], top_countries_0_14['2022_x'], color='skyblue', label='Age 0-14')
ax.bar(top_countries_0_14['Country Name'], top_countries_0_14['2022_y'], bottom=top_countries_0_14['2022_x'], color='green', label='Age 15-64')
ax.bar(top_countries_0_14['Country Name'], top_countries_0_14['2022'], bottom=top_countries_0_14['2022_x'] + top_countries_0_14['2022_y'], color='purple', label='Age 65+')
ax.set_title('Population Distribution in 2022 for Top 10 Countries by Age 0-14', fontsize=14)
ax.legend(loc=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## <center> Age Distribution 15-64 <center>

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# Plot a stacked bar chart for Age Group 15-64
ax.bar(top_countries_15_64['Country Name'], top_countries_15_64['2022_x'], color='skyblue', label='Age 0-14')
ax.bar(top_countries_15_64['Country Name'], top_countries_15_64['2022_y'], bottom=top_countries_15_64['2022_x'], color='green', label='Age 15-64')
ax.bar(top_countries_15_64['Country Name'], top_countries_15_64['2022'], bottom=top_countries_15_64['2022_x'] + top_countries_15_64['2022_y'], color='purple', label='Age 65+')
ax.set_title('Population Distribution in 2022 for Top 10 Countries by Age 15-64', fontsize=14)
ax.legend(loc=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## <center> Age Distribution 65+ <center>

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# Plot a stacked bar chart for Age Group 65+
ax.bar(top_countries_65['Country Name'], top_countries_65['2022_x'], color='skyblue', label='Age 0-14')
ax.bar(top_countries_65['Country Name'], top_countries_65['2022_y'], bottom=top_countries_65['2022_x'], color='green', label='Age 15-64')
ax.bar(top_countries_65['Country Name'], top_countries_65['2022'], bottom=top_countries_65['2022_x'] + top_countries_65['2022_y'], color='purple', label='Age 65+')
ax.set_title('Population Distribution in 2022 for Top 10 Countries by Age 65+', fontsize=14)
ax.legend(loc=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## <center> 5.4 ) Population Distribution Over Time <center>

# %% [markdown]
# ## Function Code⬇️

# %%
def plot_population_distribution(countries):
    for country in countries["Country Name"]:
        fig, ax = plt.subplots()
        
        for dataset, age_group in [(pop_14, '0-14'), (pop_15_64, '15-64'), (pop_65, '65+')]:
            country_data = dataset[dataset["Country Name"] == country]
            ax.plot(range(1960, 2023), country_data.loc[:, '1960':'2022'].values[0], label=age_group)
        
        ax.legend()
        ax.set_title('Population Distribution Over Time for ' + country)
        ax.set_xlabel('Year')
        ax.set_ylabel('Population')
        plt.show()

# %% [markdown]
# ## We are going to draw a Plot for each Country in Top 10 Countries in every Age Group.

# %%
plot_population_distribution(top_countries_0_14);

# %%
plot_population_distribution(top_countries_15_64);

# %%
plot_population_distribution(top_countries_65);

# %% [markdown]
# ## Population Distribution Over Time for the Most Populated Countries

# %%
# Get the names of the first 5 countries in the most_populated_countries dataset
top_5_countries = most_populated_countries["Country Name"].head(5)

for country in top_5_countries:
    fig, ax = plt.subplots()
    
    for dataset, age_group in [(pop_14,'0-14'), (pop_15_64,'15-64'), (pop_65, '65+')]:
        country_data = dataset[dataset["Country Name"] == country]
        ax.plot(range(1960, 2023), country_data.loc[:, '1960':'2022'].values[0], label=age_group)
    
    ax.legend()
    ax.set_title('Population Distribution Over Time for ' + country)
    ax.set_xlabel('Year')
    ax.set_ylabel('Population')

# %% [markdown]
# ### The trends we've observed and analyzed for the three distinct age groups - 0 to 14 years, 15 to 64 years, and 65 years and above - offer us rich insights into the demographic shifts that have been unfolding over the decades in these heavily populated nations.
#
# ### These shifting demographics paint a picture of a world where some countries are experiencing a youth boom, while others are grappling with an aging population. Such shifts can have profound impacts on a nation's economy, social structure, and overall development.
#
# > ####  1. For countries with a youthful population, there lies the potential of a "demographic dividend", where a large workforce can lead to rapid economic growth. However, this also brings the challenge of providing sufficient employment opportunities and managing societal changes.
#
# > ####  2. On the other hand, nations with an increasing older population need to manage a different set of challenges. These may include ensuring adequate healthcare facilities, creating a sustainable pension system, and possibly dealing with a shrinking workforce.

# %% [markdown]
# <!-- ### In our project, we've been able to delve into these facets by making use of various data visualization techniques - bar graphs, stacked bar graphs, line plots, and more. Each type of visualization has helped us understand a different aspect of the data and enabled us to unearth trends and patterns in a way that raw numbers couldn't have done. -->

# %% [markdown]
# ## <center> 5.5 ) Age Dependency Ratio Analysis <center>

# %% [markdown]
# ### In this section, we will analyze the age dependency ratio, which provides insights into the balance between the economically productive population (typically aged between 15 to 64 years) and the dependent population (those under 15 and over 64).
#
# ### Age dependency ratio is a key indicator of the socioeconomic dynamics of a country and can influence factors such as social security systems, public health planning, and national economic models.
#
# We will follow these steps:
#
#     a. Calculate the dependency ratio for each country.
#     b.Plot the dependency ratios to visualize the differences among countries.
#     c.Discuss insights and potential implications.
#
# >To calculate the dependency ratio, we'll use the following formula:
#
# >> #### Dependency Ratio = ((Population aged 0-14 + Population aged 65+) / Population aged 15-64) * 100
#
# >This ratio tells us the number of dependents per 100 working-age persons.

# %%
# Calculate dependency ratios
pop_14['2022'] = pop_14['2022'].astype(float)
pop_15_64['2022'] = pop_15_64['2022'].astype(float)
pop_65['2022'] = pop_65['2022'].astype(float)

dependency_ratio = ((pop_14['2022'] + pop_65['2022']) / pop_15_64['2022']) * 100

# Add to the combined dataframe
combined['Dependency Ratio'] = dependency_ratio

# Sort the countries by dependency ratio in descending order
sorted_dependency_ratio = combined.sort_values('Dependency Ratio', ascending=False)

# Print top countries with highest dependency ratio
print(sorted_dependency_ratio.head())
# Out:
#               Country Name     1960_x     1961_x     1962_x     1963_x  \
# 172                Senegal  43.509502  43.638216  43.775798  43.943905
# 34         Channel Islands  21.215077  21.298254  21.305170  21.251223
# 212  Virgin Islands (U.S.)  37.543934  35.639179  35.896036  36.054743
# 157       Papua New Guinea  43.232346  43.488293  43.775119  44.073691
# 43              Cabo Verde  43.595022  44.306841  45.001896  45.559593
#
#         1964_x     1965_x     1966_x     1967_x     1968_x  ...       2014  \
# 172  44.174950  44.289672  44.238316  44.170094  44.095365  ...   3.164862
# 34   21.166865  21.108228  21.112939  21.174742  21.270860  ...  16.540045
# 212  36.219075  36.496122  36.707243  36.712004  36.526386  ...  16.638132
# 157  44.375793  44.697557  45.032940  45.378054  45.722105  ...   2.720798
# 43   45.987088  46.248206  46.344920  46.324161  46.203985  ...   5.419392
#
#           2015       2016       2017       2018       2019       2020  \
# ...

# %% [markdown]
# ## Visualizing the Dependency Ratio
#
# #### To gain a more detailed understanding of the distribution and time trend of the dependency ratio, we selected the top five countries with the highest dependency ratio in 2022. These countries include Senegal, Channel Islands, Virgin Islands (U.S.), Papua New Guinea, and Cabo Verde.
#
# #### We then reshaped the data into a 'long' format, which is easier to use with the seaborn plotting library. Each row of the long format data represents a single observation for a year and a country.
#
# #### Next, we plotted two types of plots:
#
#     1. Violin Plot: This plot provides a way to visualize both the distribution and the
#                     probability density of the data. The width of the 'violin' at any given
#                     y-value (dependency ratio) shows the estimated likelihood of that ratio.
#                     The 'violin' is symmetrical, with its left and right halves mirroring each other.
#
#     2. Point Plot: This plot shows the trend of dependency ratio over time
#                    for the  five selected countries. Each line represents a country,
#                    and the y-value of a point at any given x-value (year) shows the
#                    dependency ratio of that country in that year.

# %%
top_5_countries = sorted_dependency_ratio.head(5)['Country Name']

# Convert the data to long format for seaborn plotting
long_format_data = pd.melt(combined[combined['Country Name'].isin(top_5_countries)], 
                           id_vars='Country Name', 
                           value_vars=[str(year) for year in range(1960, 2023)], 
                           var_name='Year', 
                           value_name='Unique Dependency Ratio')  # change here

long_format_data['Year'] = long_format_data['Year'].astype(int)

plt.figure(figsize=(15, 10))

# Plotting violin plot
sns.violinplot(x='Country Name', y='Unique Dependency Ratio', data=long_format_data)  # change here
plt.title('Violin plot showing distribution of Dependency Ratios for top 5 countries from 1960 to 2022')
plt.show()

plt.figure(figsize=(15, 10))

# Plotting point plot
sns.pointplot(x='Year', y='Unique Dependency Ratio', hue='Country Name', data=long_format_data)  # change here
plt.title('Point plot showing evolution of Dependency Ratios for top 5 countries from 1960 to 2022')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualize evolution of dependency ratio over time for the top 5 countries
top_5_countries = sorted_dependency_ratio.head(5)['Country Name']
for country in top_5_countries:
    plt.figure(figsize=(10,6))
    plt.plot(combined.loc[combined['Country Name']==country, '1960':'2022'].values[0])
    plt.title(f'Dependency Ratio Evolution for {country} from 1960 to 2022')
    plt.xlabel('Year')
    plt.ylabel('Dependency Ratio')
    plt.show()

# %% [markdown]
# ### In the ever-evolving landscape of global economics, the analysis of Gross Domestic Product (GDP) serves as a vital lens through which we can understand the progress, challenges, and trends within a country's economy. GDP encapsulates the total value of goods and services produced within a nation's borders, reflecting its economic strength, growth, and standard of living. By examining the GDP trajectories of various countries over time, we can gain valuable insights into their economic development, structural changes, and the factors that have shaped their paths.
#
# ### This analysis aims to focus on the evolution of GDP in different countries, shedding light on their unique economic journeys. By delving into historical data and trends, we can explore how countries have navigated through periods of growth, recession, and transformation. Moreover, we can examine the factors that have influenced their GDP, such as government policies, technological advancements, natural resources, trade dynamics, and socio-economic factors.

# %% [markdown]
# ## 5.6 ) Incorporating GDP Data for Further Analysis:

# %% [markdown]
# ### With a solid understanding of the population distribution and age distribution in various countries, we can now extend our analysis by incorporating economic data. Particularly, we are interested in examining how population growth and age distribution affect a country's Gross Domestic Product (GDP).

# %% [markdown]
# > #### GDP is one of the primary indicators used to gauge the health of a country's economy. It represents the total dollar value of all goods and services produced over a specific time period. Understanding the relationship between a country's GDP and its population structure can provide significant insights.
#
# ### Below, we'll incorporate GDP data into our project and apply the same data cleaning methodoligies we used earlier

# %%
import pandas as pd

# Load the GDP data
gdp_data = pd.read_csv('gdp.csv')

# Display the first few rows of the data
print(gdp_data.head())
# Out:
#                   Country Name          1960          1961          1962  \
# 0                        Aruba           NaN           NaN           NaN
# 1  Africa Eastern and Southern  2.112502e+10  2.161623e+10  2.350628e+10
# 2                  Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08
# 3   Africa Western and Central  1.044764e+10  1.117321e+10  1.199053e+10
# 4                       Angola           NaN           NaN           NaN
#
#            1963          1964          1965          1966          1967  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.804836e+10  2.592067e+10  2.947210e+10  3.201437e+10  3.326951e+10
# 2  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09
# 3  1.272769e+10  1.389811e+10  1.492979e+10  1.591084e+10  1.451058e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            1968  ...          2013          2014          2015          2016  \
# ...

# %%
gdp_data = clean_data(gdp_data)

# %% [markdown]
# ## Handling Missing Data
#
# #### As part of the data cleaning process, it's crucial to handle missing values in the dataset. In our GDP data, there are certain years for which GDP information is missing for some countries. These missing values can cause issues when performing subsequent data analysis or building models.
#
# #### Therefore, we adopted the following approach to handle the missing GDP data:
#
# 1. **Interpolation**: The idea behind interpolation is to use the values of the years preceding and following the missing year to estimate the value for that year. We used linear interpolation, which calculates the average of the last and next year's values to fill in the missing cell. This method assumes that the change in GDP from year to year is linear, which is a reasonable assumption for short periods.
#
# 2. **Median Imputation**: However, there might be situations where the missing year is the first or last year, meaning we don't have both a preceding and following year to use for interpolation. In these cases, we used median imputation, where the missing value is replaced with the median value of the available GDP values for that country. The median is a robust measure of central tendency, which means it's less affected by outliers in the data than the mean.
#
# ### By handling missing data, we ensure that our data analysis is based on a complete dataset and therefore more reliable.

# %%
import pandas as pd
import numpy as np

# Load your data
# gdp_data = pd.read_csv("your_file_path.csv")

# For each column (year) in the DataFrame, interpolate missing values using 'linear' method
for column in gdp_data.columns[1:]:  # We start from index 1 to skip the 'Country Name' column
    gdp_data[column] = gdp_data[column].interpolate(method='linear', limit_direction='both')

# If there are still any missing values, fill them with the median value of each country's GDP data
for column in gdp_data.columns[1:]:
    gdp_data[column].fillna(gdp_data[column].median(), inplace=True)

print(gdp_data.head())
# Out:
#   Country Name          1960          1961          1962          1963  \
# 0        Aruba  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2  Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 4       Angola  2.545421e+09  2.674888e+09  5.327454e+09  4.255314e+09
# 5      Albania  4.553063e+09  4.800888e+09  1.010824e+10  7.759516e+09
# 6      Andorra  6.560706e+09  6.926887e+09  1.488903e+10  1.126372e+10
#
#            1964          1965          1966          1967          1968  ...  \
# 0  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  ...
# 2  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  ...
# 4  5.761050e+09  6.474275e+09  6.846095e+09  6.190000e+09  6.386038e+09  ...
# 5  1.072210e+10  1.194188e+10  1.229219e+10  1.070667e+10  1.139874e+10  ...
# 6  1.568315e+10  1.740949e+10  1.773828e+10  1.522333e+10  1.641145e+10  ...
#
#            2013          2014          2015          2016          2017  \
# ...

# %% [markdown]
# ## GDP Analysis
#
# ### In this section, we will explore the GDP dataset and generate insights from it. We aim to understand how the GDP of different countries has changed over time and how it relates to their population and age distributions.
#
# ### GDP Trends Over Time
#
# we will take a look at the evolution of GDP over time for the top 10 countries in GDP in 2022. This will help us understand the overall economic growth trend and identify periods of rapid growth or economic downturns.

# %%
top_countries_2022 = gdp_data.sort_values('2022', ascending=False)['Country Name']
top_countries_2022
# Out:
# 250                     United States
# 40                              China
# 118                             Japan
# 55                            Germany
# 109                             India
# 81                     United Kingdom
# 77                             France
# 108                       Isle of Man
# 201                Russian Federation
# 35                             Canada
# 115                             Italy
# 29                             Brazil
# 13                          Australia
# 125                       Korea, Rep.
# 153                            Mexico
# 70                              Spain
# 78                      Faroe Islands
# 106                         Indonesia
# 204                      Saudi Arabia
# 175                       Netherlands
# 69                            Eritrea
# 243                           Turkiye
# 37                        Switzerland
# 189                            Poland
# 217                      Small states
# ...

# %%
import matplotlib.pyplot as plt

# def plot_population_growth(countries, start_year, end_year, num_countries):
#     # Create an empty plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot population growth for each country
for country in top_countries_2022[:10]:
    country_data = gdp_data[gdp_data["Country Name"] == country]
    years = range(1960, 2023)  # Update this range with the desired start and end years
    GDP = country_data.loc[:, str(years[0]):str(years[-1])].values[0]
    ax.plot(years, GDP, label=country)

# Add legend, title, and labels
ax.legend()
ax.set_title('GDP Growth Over Time ({}-{})'.format(1960, 2022))
ax.set_xlabel('Year')
ax.set_ylabel('GDP')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       5 fig, ax = plt.subplots(figsize=(12, 8))
#       7 # Plot population growth for each country
# ----> 8 for country in top_countries_2022[:10]:
#       9     country_data = gdp_data[gdp_data["Country Name"] == country]
#      10     years = range(1960, 2023)  # Update this range with the desired start and end years
#
# NameError: name 'top_countries_2022' is not defined

# %%
most_populated_countries = populationData.sort_values('2022', ascending=False).head(20)
print(most_populated_countries.head())

# %% [markdown]
# ## After careful examination of our global GDP and population data from 1960 to 2022, we're concluding our analysis with a visualization focusing on the top five most populated countries. These nations represent a significant fraction of the world's total population and, consequently, have substantial economic weight.
#
# ### The ultimate visualization, which highlights each country's GDP growth over the corresponding years, provides us with a visual storyline of their economic journey. Comparing the rates and patterns of GDP growth can give us insights into how various factors, including population size, can impact a country's economic progress. It can also illuminate the effectiveness of different economic policies and models across these diverse nations.
#
# ### In a globalized world, understanding these patterns is essential to international policy-making, business strategy, and even individual investment decisions.
#
# > Please note: This is a historical analysis and may not directly predict future trends as economic progress is influenced by a multitude of factors beyond population size.

# %%
import matplotlib.pyplot as plt

# Extract top 5 most populated countries
top_countries_pop = most_populated_countries['Country Name'].head(5)

# Get the GDP data for these countries
top_countries_gdp = gdp_data[gdp_data['Country Name'].isin(top_countries_pop)]

fig, ax = plt.subplots(figsize=(15, 10))

# Plot GDP growth for each country
for i, country in top_countries_gdp.iterrows():
    years = range(1960, 2023)
    GDP = country.loc[str(years[0]):str(years[-1])].values
    ax.plot(years, GDP, label=country['Country Name'])

# Add legend, title, and labels
ax.legend()
ax.set_title('GDP Growth Over Time (1960-2022) for Top 5 Populated Countries')
ax.set_xlabel('Year')
ax.set_ylabel('GDP')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 import matplotlib.pyplot as plt
#       3 # Extract top 5 most populated countries
# ----> 4 top_countries_pop = most_populated_countries['Country Name'].head(5)
#       6 # Get the GDP data for these countries
#       7 top_countries_gdp = gdp_data[gdp_data['Country Name'].isin(top_countries_pop)]
#
# NameError: name 'most_populated_countries' is not defined

# %%
for i, country in top_countries_gdp.iterrows():
    print(f"Country: {country['Country Name']}")
    print(f"GDP in 1960: ${country['1960']:.2f}")
    print(f"GDP in 2022: ${country['2022']:.2f}")
    print(f"Growth: {((country['2022'] - country['1960']) / country['1960']) * 100:.2f}%")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 for i, country in top_countries_gdp.iterrows():
#       2     print(f"Country: {country['Country Name']}")
#       3     print(f"GDP in 1960: ${country['1960']:.2f}")
#
# NameError: name 'top_countries_gdp' is not defined

# %% [markdown]
# ## The data visualizations and corresponding numeric values provide rich insights into the economic progress of these nations.
#
#     a. China: With a staggering 29,980.87% growth in GDP from 1960 to 2022, China has
#               experienced phenomenal economic progress. Despite being the most populous country,
#               China managed to effectively leverage its population size, implementing significant
#               economic reforms, and making substantial investments in education,
#               technology, and infrastructure.
#
#     b. Indonesia: Although Indonesia's population is significantly smaller than China's or India's, its
#                  6972.34% GDP growth rate shows an impressive economic expansion. This suggests that factors
#                  other than population size, such as the utilization of natural resources, strategic
#                  economic planning, and stable political climate, have contributed to its progress.
#
#     c. India: India, the second-most populous country, has shown a substantial GDP growth of 9041.51%.
#               This showcases the impact of India's shift from an agrarian economy towards a
#               market-driven economy, significant technological advancement, and rapid urbanization.
#
#     d. Pakistan: Pakistan's economic progress, with a 9942.84% GDP growth, illustrates the
#                  nation's strides in certain sectors like telecommunications, textiles, and construction,
#                  despite ongoing challenges related to political stability and infrastructure development.
#
#     e.United States: Although the US is not among the top five most populous nations,
#                      its GDP growth rate stands at an impressive 4586.67%. This underlines the fact
#                      that a large population is not the only driver for economic growth.
#                      The US has been able to achieve this growth due to factors like technological
#                      innovation, a highly developed infrastructure, abundant natural
#                      resources, and high productivity levels.

# %% [markdown]
# # 6. Ethical Considerations
#
# ## 6.1 Data Source and Licensing
#
# The datasets used in this project are publicly available from the World Bank, a reputable international financial institution. The data is provided under a [Creative Commons Attribution 4.0 International license](https://creativecommons.org/licenses/by/4.0/), which allows for the reuse, distribution, and remixing of the data, provided that appropriate credit is given to the World Bank.
#
# ## 6.2 Usage and Reusage of Data
#
# While the World Bank data is openly licensed and free to use, it is important to consider the potential ethical implications of its use and reusage. The data should be used responsibly and with an understanding of what it represents. Inaccurate interpretation or misuse can lead to misinformed decisions or policies. Users of this data are urged to understand the context in which the data was collected and to use it in a way that respects this context.
#
# ## 6.3 Implications of Data Utilization
#
# The use of this demographic and economic data has far-reaching implications. It can influence policy decisions, research directions, and public understanding of crucial global issues. While these influences can be positive when the data is used responsibly, misuse or misinterpretation can lead to negative outcomes. It is therefore essential that this data is analyzed and communicated with care, accuracy, and transparency.
#
# ## 6.4 Data Bias and Fairness
#
# Despite the broad scope of the World Bank data, there are inherent biases that users need to be aware of. Not all countries or regions may be equally represented, and data collection methods may vary, leading to potential discrepancies. Furthermore, the data primarily reflects macroeconomic indicators and demographics, and may not capture other important aspects such as income inequality, social disparities, or subjective measures of well-being. As such, any analysis should take these limitations into account to avoid reinforcing or perpetuating any potential biases.

# %% [markdown]
# # 7. Data Modifications
#
# ## 7.1 Data Transformations
#
# Our analysis involved several critical transformations to make the data suitable for the planned explorations.
#
# 1. **Data Cleaning:** This was a crucial step in ensuring the quality and reliability of our analysis. We cleaned the datasets to handle missing values and inconsistencies, replacing missing data with appropriate statistical measures or using interpolation methods where suitable. Furthermore, we created a custom function to remove non-country entities like continents, unions, and large portions of the world, ensuring that our dataset strictly represented countries. Irrelevant columns, such as country codes and a blank column at the end of the data, were also removed manually.
#
# 2. **Data Reshaping:** The raw GDP data from the World Bank was in a wide format. To make this data easier to handle, we reshaped it into a long format using the pandas `melt` function in Python. This transformation improved the data's readability and manageability for analysis.
#
# 3. **Feature Engineering:** To provide more insights, we created new features from existing data. For example, the 'Population Growth' and 'Growth Rate' were calculated from the available population data.
#
# ## 7.2 Justification for Modifications
#
# Data cleaning was indispensable for minimizing errors and inaccuracies that could arise from poor-quality data. The removal of non-country entities and irrelevant columns resulted in a more focused and relevant dataset, providing a more accurate representation of the world's demographic landscape. Reshaping the GDP data from wide to long format facilitated a more efficient data handling process, enhancing our analysis. Additionally, feature engineering enriched our dataset, allowing for a more detailed exploration of demographic trends.
#
# ## 7.3 Value Addition through Modifications
#
# The modifications to our dataset significantly increased the value of our analysis. Data cleaning and the removal of non-country entities improved the accuracy of our findings. The wide-to-long reshaping of the GDP data made it more manageable and contributed to a smoother analysis process. The engineered features offered additional dimensions for exploration, revealing insights that were not immediately apparent from the raw data.

# %% [markdown]
# ## <center> 8. Summary <center>

# %% [markdown]
# ### 8.1) Conclusion
#
# #### Throughout our journey of exploratory data analysis, we have delved deep into the world's most populous countries' demographic shifts, trends, and age distributions. Our exploration unveiled distinct patterns and trends in different age groups across countries and across time. This dataset's exploration, therefore, offers a promising prospect for more nuanced studies - for instance, socio-economic implications of an aging population, youth unemployment, and more.
#
# > It would also be valuable to introduce further dimensions to our analysis, like gender-based population distribution, urban vs. rural populace, etc., which would further enrich our understanding of the demographic dynamics.

# %% [markdown]
# ### 8.2) Summary of Used Data
# #### 8.2.1 Total Population & Population Distribution Datasets:
# The column details of our 4 main datasets -populationData, pop_14, pop_15_64, and pop_65 - are as follows:

# %%
print("Columns in pop_14: \n", pop_14.columns)
print("Columns in pop_15_64: \n", pop_15_64.columns)
print("Columns in pop_65: \n", pop_65.columns)
print("Columns in poppopulation Dataset: \n", populationData.columns)
# Out:
# Columns in pop_14:
#  Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022'],
#       dtype='object')
# Columns in pop_15_64:
#  Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
# ...

# %% [markdown]
# > #### For these datasets:
#     a. 'Country Name' is used as the key column to merge and compare datasets.
#     b. The columns from '1960' to '2022' are used to plot population distribution trends over
#        time for different age groups.
#     c. These datasets were used in stacked bar charts to visualize the proportion of each age group in a
#        given year for the top 10 countries.

# %% [markdown]
# #### 8.2.2 Most Populated Countries Dataset:
# The -most_populated_countries- dataset columns:

# %%
populationData.columns
# Out:
# Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', 'Population Growth', 'Growth Rate'],
#       dtype='object')

# %% [markdown]
# > #### For this dataset:
#     a. 'Country Name' is used to identify the most populated countries.
#     b. '2022' is used to rank these countries based on their total population.
#     c. This dataset helped us identify and analyze the most populated countries.

# %% [markdown]
# #### 6.2.3 GDP Dataset:
# The GDP dataset columns:

# %%
gdp_data.columns
# Out:
# Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022'],
#       dtype='object')

# %% [markdown]
# > #### For this dataset:
#     a. 'Country Name' is the key.
#     b. The columns from '1960' to '2022' are used to plot GDP
#        trends over time for different countries.
#     c. This dataset helped us identify and analyze the top countries with GDP and also it helped us
#        in merging population data with gdp data to get insights on how population is affecting GDP

# %% [markdown]
# # 7. Conclusion
#
# ## Throughout this project, we've harnessed the power of data analysis and visualization to unravel and understand intricate patterns in global demographic and economic trends. The study of demographics, enriched by GDP analysis and the exploration of age distributions, has provided us with invaluable insights into the dynamics of our world's societies and economies.
#
# ## The compelling narrative we've drawn from numbers and visuals is a testament to the pivotal role data analysis and visualization play in deciphering the complex world around us. With a focus on the most populated countries, we've provided a comprehensive examination of population distribution across different age groups, GDP progression over the years, and the dependency ratio's influence on economies.
#
# ## Yet, our exploration has only begun to scratch the surface of the vast field of global demographic trends. Although we have constrained by the scope of our project and the timeframe, there are numerous other dimensions we could delve into for a more profound understanding. These include, but are not limited to, investigations into CO2 emissions, gender distributions, and the impacts of migration on demographics and economies.
#
# ## Despite these limitations, our project forms a robust foundation and provides a valuable starting point for anyone interested in delving deeper into global demographic trends and their far-reaching social, economic, and environmental implications. The tools, methodologies, and insights gained from this project can be readily applied and expanded upon in future research to help us better navigate the complex tapestry of our world.

# %% [markdown]
# ## 8. Resources

# %% [markdown]
# 1. The World Bank (2023). [World Development Indicators: Population estimates and projections](https://databank.worldbank.org/reports.aspx?source=world-development-indicators)
#
# 2. Hunter, J. D. (2007). Matplotlib: A 2D Graphics Environment. Computing in Science & Engineering, 9, 90-95. [DOI: 10.1109/MCSE.2007.55](https://doi.org/10.1109/MCSE.2007.55)
#
# 3. McKinney, W. (2010). Data Structures for Statistical Computing in Python. In S. van der Walt & J. Millman (Eds.), Proceedings of the 9th Python in Science Conference (pp. 51 - 56).
#
# 4. [Seaborn: statistical data visualization](https://seaborn.pydata.org/)
#
# 5. van der Walt, S., Colbert, S. C., & Varoquaux, G. (2011). The NumPy Array: A Structure for Efficient Numerical Computation. Computing in Science & Engineering, 13, 22-30. [DOI: 10.1109/MCSE.2011.37](https://doi.org/10.1109/MCSE.2011.37)
#
# 6. Python Software Foundation. Python Language Reference, version 3.7. [Available at www.python.org](https://www.python.org)
